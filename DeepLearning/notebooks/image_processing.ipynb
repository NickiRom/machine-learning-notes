# %%
import numpy as np
from scipy.misc import imread, imsave, imresize
import matplotlib.pyplot as plt
from skimage.transform import resize
import imageio

# %%
img = imageio.imread('../images/k-d_trees.png')
print(img.dtype, img.shape)

img_tinted = np.uint(img*[1,.9,.95,1])
#img_tinted = resize(img_tinted, (300,300), mode='reflect')

plt.imshow(np.uint8(img_tinted))
plt.show()

imageio.imwrite('../images/k-d_trees_tinted_resized.png', np.uint8(img_tinted))
# Out:
# (dtype('uint8'), (702, 1580, 4))

# %%
# Show the original image
plt.subplot(1, 2, 1)
plt.imshow(img)

# Show the tinted image
plt.subplot(1, 2, 2)

# A slight gotcha with imshow is that it might give strange results
# if presented with data that is not uint8. To work around this, we
# explicitly cast the image to uint8 before displaying it.
plt.imshow(np.uint8(img_tinted))
plt.show()
